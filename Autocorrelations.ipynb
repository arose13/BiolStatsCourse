# %%
from statsImport import *
from statsmodels.tsa.stattools import adfuller

# %%
x = np.linspace(0, 5*np.pi, 100)

data = pd.DataFrame(x, columns=['x'])
data['y'] = np.sin(x)

graph.title('data')
graph.plot(data.y)
graph.show()

# %%
fx = data.y+data.x**2

graph.title('Difference $y = sin(x) + x^2$ until stationary')
graph.plot(fx, label='0')
graph.plot(fx.diff(), label='1')
graph.plot(fx.diff().diff(), label='2')
graph.legend(loc=0)
graph.ylim([-5, 10])
graph.show()

print('0 order', adfuller(fx))
print('=========================\n')
print('1 order', adfuller(fx.diff().dropna()))
print('=========================\n')
print('2 order', adfuller(fx.diff().diff().dropna()))
# Out:
# 0 order (0.90895255114845053, 0.99320605435817411, 12, 87, {'1%': -3.5078527246648834, '5%': -2.8953820306361551, '10%': -2.5848238776588719}, -5188.0011879737085)
# =========================
#
# 1 order (0.0059758136844781738, 0.95902350039817486, 2, 96, {'1%': -3.5003788874873405, '5%': -2.8921519665075235, '10%': -2.5830997960069446}, -4903.0682493143786)
# =========================
#
# 2 order (-47022915651.589188, 0.0, 1, 96, {'1%': -3.5003788874873405, '5%': -2.8921519665075235, '10%': -2.5830997960069446}, -4846.9688539014005)

# %%
graph.title('lags')
graph.plot(data.y.shift(1))
graph.plot(data.y.shift(100))
graph.plot(data.y)
graph.show()

# %%
sns.jointplot(data.y, data.y.shift(5))
graph.show()

sns.jointplot(data.y, data.y.diff().diff())
graph.show()

# %%
pd.tools.plotting.autocorrelation_plot(data.y)
graph.show()

# %%
sns.distplot(np.random.normal(scale=0.05,size=1e6))
graph.show()

# %%
data.y.plot()
graph.plot(data.y + np.random.normal(scale=0.5, size=len(data.y)))
graph.show()

#sns.jointplot(data.y, data.y + np.random.normal(scale=0.5, size=(len(data.y))))
sns.jointplot(data.y, data.y.shift(5))
graph.show()
